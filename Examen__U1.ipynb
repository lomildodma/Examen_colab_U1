# %% [markdown]
# <a href="https://colab.research.google.com/github/lomildodma/Examen_colab_U1/blob/main/Examen__U1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Evaluación. Tema 1.
# Analítica de Datos

# %% [markdown]
# Nombre de los integrantes del equipo

# %% [markdown]
# AVILA PÉREZ LUIS EFRÉN
#
#
# SEGURA MARTINES LUIS ROBERTO

# %% [markdown]
# ## Introducción
#
# En estos ejercicios vamos a trabajar con el dataset alojado en la ruta: **/
# datasets/harvard_reviews.csv**
#
# Ejecuta la siguiente celda para el dataframe con el contenido del dataset.

# %%
import pandas as pd
reviews = pd.read_csv("datasets/harvard_reviews.csv")
reviews.head()
# Out:
#               published_date published_platform  rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 2  2023-12-10T08:21:35-05:00             Mobile       3  review
# 3  2023-11-07T21:20:21-05:00            Desktop       4  review
# 4  2023-10-02T17:40:42-04:00            Desktop       5  review
#
#    helpful_votes                                              title  \
# 0              0                 Best classes and good environment
# 1              0                                 Harvard University
# 2              0                                 Walk around campus
# 3              0                     Interesting Harvard University
# 4              0  Lovely university campus has many historic and...
#
#                                                 text
# 0  Good thanks for everything good work group 👍 h...
# 1  Harvard University was founded in 1636 and is ...
# 2  We did a walk around most of the Harvard Campu...
# 3  We had a walk through the university grounds w...
# 4  Finally made it to Harvard!!  This iconic univ...

# %% [markdown]
# ## Ejercicio 1
#
# Selecciona la columna ``text`` del dataframe reviews y asignalo a una variable llamada ``col_texto``

# %%
col_texto = reviews['text']
col_texto
# Out:
# 0       Good thanks for everything good work group 👍 h...
# 1       Harvard University was founded in 1636 and is ...
# 2       We did a walk around most of the Harvard Campu...
# 3       We had a walk through the university grounds w...
# 4       Finally made it to Harvard!!  This iconic univ...
#                               ...
# 3179    wenn man in boston ist hat manmeistens zeit au...
# 3180    Von der Führung der Harvard University erhofft...
# 3181    da vedere questa città, studio sede di una del...
# 3182    Hallo,\nich habe ein Jahr an der Harvard Law S...
# 3183    とても歴史のある素敵な建物です。ハーバードスクエアーの駅の近くから無料のツアー（英語）をハー...
# Name: text, Length: 3184, dtype: object

# %% [markdown]
# Pregunta complementaria: ¿qué tipo de objeto es **col_texto**? Si no estás seguro, puedes comprobarlo llamando a la función type de Python: type(desc). texto en cursiva
#
# Rerspuesta: Cuando seleccionamos una columna o variable sola, lo que obtenemos es un objeto Serie con su índice respectivo.

# %% [markdown]
# ## Ejercicio 3
#
# Selecciona la primera fila de datos (el primer registro) de `reviews`, asignándola a la variable `primera_fila`.

# %%
primera_fila = reviews.iloc[0]
primera_fila
# Out:
# published_date                                2023-12-28T08:02:14-05:00
# published_platform                                               Mobile
# rating                                                                5
# type                                                             review
# helpful_votes                                                         0
# title                                Best classes and good environment
# text                  Good thanks for everything good work group 👍 h...
# Name: 0, dtype: object

# %% [markdown]
# ## Ejercicio 4
#
# Selecciona los 10 primeros valores de la columna `title` en `reviews`, asignando el resultado a la variable `primeros_titulos`.
#
# Sugerencia: formatea su salida como una Serie pandas.

# %%
primeros_titulos = reviews['title'].head(10)
primeros_titulos
# Out:
# 0                   Best classes and good environment
# 1                                   Harvard University
# 2                                   Walk around campus
# 3                       Interesting Harvard University
# 4    Lovely university campus has many historic and...
# 5       Interesting walk around campus grounds & river
# 6                                  Inspirational place
# 7               Harvard University student guided tour
# 8                            Beautiful historic campus
# 9                                          Nice campus
# Name: title, dtype: object

# %% [markdown]
# ## Ejercicio 5
#
# Selecciona los registros con etiquetas de índice `1`, `2`, `3`, `5` y `8`, asignando el resultado a la variable `reviews_filtradas`.
#
# En otras palabras, genere el siguiente DataFrame:
#
# <img src="imgs/ej-05.PNG">

# %%
reviews_filtradas = reviews.loc[[1, 2, 3, 5, 8]]
reviews_filtradas
# Out:
#               published_date published_platform  rating    type  \
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 2  2023-12-10T08:21:35-05:00             Mobile       3  review
# 3  2023-11-07T21:20:21-05:00            Desktop       4  review
# 5  2023-09-29T08:44:17-04:00            Desktop       4  review
# 8  2023-07-02T11:55:51-04:00            Desktop       4  review
#
#    helpful_votes                                           title  \
# 1              0                              Harvard University
# 2              0                              Walk around campus
# 3              0                  Interesting Harvard University
# 5              0  Interesting walk around campus grounds & river
# 8              2                       Beautiful historic campus
#
#                                                 text  rating_europe
# 1  Harvard University was founded in 1636 and is ...              8
# 2  We did a walk around most of the Harvard Campu...              6
# 3  We had a walk through the university grounds w...              8
# 5  Very interesting to wander around the grounds ...              8
# 8  The beauty, charm, and architecture of so many...              8

# %% [markdown]
# ## Ejercicio 6
#
# Crea una variable `df` que contenga las columnas `published_platform`, `rating`, `type` y `helpful_votes` de los registros con las etiquetas de índice `0`, `1`, `10` y `100`. En otras palabras, genera el siguiente DataFrame:

# %%
df = reviews.loc[[0, 1, 10, 100], ['published_platform', 'rating', 'type', 'helpful_votes']]
df
# Out:
#     published_platform  rating    type  helpful_votes
# 0               Mobile       5  review              0
# 1              Desktop       4  review              0
# 10              Mobile       4  review              0
# 100             Mobile       3  review              2

# %% [markdown]
# ## Ejercicio 7
#
# Crea una variable `df` que contenga las columnas `title` y `text` de los 100 primeros registros.

# %%
df = reviews.loc[:99, ['title', 'text']]
df
# Out:
#                                                 title  \
# 0                  Best classes and good environment
# 1                                  Harvard University
# 2                                  Walk around campus
# 3                      Interesting Harvard University
# 4   Lovely university campus has many historic and...
# ..                                                ...
# 95                               So historic, just go
# 96                     A most prestigious university
# 97                                      Great History
# 98                                Gorgeous Campus!!!
# 99        Harvard University walking tour by students
#
#                                                  text
# 0   Good thanks for everything good work group 👍 h...
# 1   Harvard University was founded in 1636 and is ...
# 2   We did a walk around most of the Harvard Campu...
# 3   We had a walk through the university grounds w...
# 4   Finally made it to Harvard!!  This iconic univ...
# ..                                                ...
# 95  If you’re touring in Boston, why wouldn’t you ...
# 96  There's a river between a Harvard undergraduat...
# 97  We had a great tour of the university and the ...
# 98  Harvard is gorgeous and while we were visiting...
# 99  Xiadi our tour guide was very entertaining but...
#
# [100 rows x 2 columns]

# %% [markdown]
# ## Ejercicio 8
#
# Crea un DataFrame llamado `harvard_rating` que contenga los registros donde los valores de la columna `rating` sean mayor que 3.

# %%
harvard_rating = reviews[reviews['rating'] > 3]
harvard_rating
# Out:
#                  published_date published_platform  rating    type  \
# 0     2023-12-28T08:02:14-05:00             Mobile       5  review
# 1     2023-12-12T00:38:26-05:00            Desktop       4  review
# 3     2023-11-07T21:20:21-05:00            Desktop       4  review
# 4     2023-10-02T17:40:42-04:00            Desktop       5  review
# 5     2023-09-29T08:44:17-04:00            Desktop       4  review
# ...                         ...                ...     ...     ...
# 3177  2011-03-27T05:58:59-04:00            Desktop       4  review
# 3178  2010-12-27T03:28:05-05:00            Desktop       5  review
# 3181  2010-08-23T00:06:41-04:00            Desktop       5  review
# 3182  2010-06-03T07:37:36-04:00            Desktop       5  review
# 3183  2009-09-27T16:39:18-04:00            Desktop       5  review
#
#       helpful_votes                                              title  \
# 0                 0                 Best classes and good environment
# 1                 0                                 Harvard University
# 3                 0                     Interesting Harvard University
# 4                 0  Lovely university campus has many historic and...
# 5                 0     Interesting walk around campus grounds & river
# ...             ...                                                ...
# 3177              1          Ganz gemütlich über den Campus schlendern
# 3178              0         beeindruckender Campus - alles first class
# 3181              0                              bellissima università
# 3182              2  Tolle Universität, definitiv einen Abstecher wert
# 3183              1                                            一度は行くべき
#
#                                                    text
# 0     Good thanks for everything good work group 👍 h...
# 1     Harvard University was founded in 1636 and is ...
# 3     We had a walk through the university grounds w...
# 4     Finally made it to Harvard!!  This iconic univ...
# 5     Very interesting to wander around the grounds ...
# ...                                                 ...
# 3177  Wenn man in Boston ist, sollte man auf jeden F...
# 3178  habe eine Tour durch über 10 Campusse der best...
# 3181  da vedere questa città, studio sede di una del...
# 3182  Hallo,\nich habe ein Jahr an der Harvard Law S...
# 3183  とても歴史のある素敵な建物です。ハーバードスクエアーの駅の近くから無料のツアー（英語）をハー...
#
# [2860 rows x 7 columns]

# %% [markdown]
# ## Ejercicio 9
#
# Crea un DataFrame llamado `harvard_mobile` que contenga los registros donde los valores de la columna `rating` sean mayor que 3 y además las reviews se hayan hecho por el móvil.
#
# Pista: Fíjate en la columna `published_platform`

# %%
harvard_mobile = reviews[(reviews['rating'] > 3) & (reviews['published_platform'] == 'mobile')]
harvard_mobile
# Out:
# Empty DataFrame
# Columns: [published_date, published_platform, rating, type, helpful_votes, title, text]
# Index: []

# %% [markdown]
# ## Ejercicio 10
#
# Añade una nueva columna al dataframe de `reviews` llamada `rating_europe` en la cuál se debe almacenar los valores de la columna `rating` multiplicados por 2.

# %%
reviews['rating_europe'] = reviews['rating'] * 2
reviews.head()
# Out:
#               published_date published_platform  rating    type  \
# 0  2023-12-28T08:02:14-05:00             Mobile       5  review
# 1  2023-12-12T00:38:26-05:00            Desktop       4  review
# 2  2023-12-10T08:21:35-05:00             Mobile       3  review
# 3  2023-11-07T21:20:21-05:00            Desktop       4  review
# 4  2023-10-02T17:40:42-04:00            Desktop       5  review
#
#    helpful_votes                                              title  \
# 0              0                 Best classes and good environment
# 1              0                                 Harvard University
# 2              0                                 Walk around campus
# 3              0                     Interesting Harvard University
# 4              0  Lovely university campus has many historic and...
#
#                                                 text  rating_europe
# 0  Good thanks for everything good work group 👍 h...             10
# 1  Harvard University was founded in 1636 and is ...              8
# 2  We did a walk around most of the Harvard Campu...              6
# 3  We had a walk through the university grounds w...              8
# 4  Finally made it to Harvard!!  This iconic univ...             10

# %% [markdown]
# **Autoevaluación:**. En una escala del 6 al 10, donde 6 es el más bajo nivel de desempeño y 10 el más alto nivel, describa la calificación que se colocarían en el tema 1.

# %%
#90
